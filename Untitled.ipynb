# %%
#import dependencies
import pandas as pd

# %%
# read in csv data and create a dataframe

filepath = "resources/assets/heart.csv"

heart_df = pd.read_csv(filepath)

# %%
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
sample_df = heart_df.head(40)

# %%
sample_df
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    52    1   0       125   212    0        1      168      0      1.0
# 1    53    1   0       140   203    1        0      155      1      3.1
# 2    70    1   0       145   174    0        1      125      1      2.6
# 3    61    1   0       148   203    0        1      161      0      0.0
# 4    62    0   0       138   294    1        1      106      0      1.9
# 5    58    0   0       100   248    0        0      122      0      1.0
# 6    58    1   0       114   318    0        2      140      0      4.4
# 7    55    1   0       160   289    0        0      145      1      0.8
# 8    46    1   0       120   249    0        0      144      0      0.8
# 9    54    1   0       122   286    0        0      116      1      3.2
# 10   71    0   0       112   149    0        1      125      0      1.6
# 11   43    0   0       132   341    1        0      136      1      3.0
# ...

# %%
# convert the dataframe to an html table

html_table = sample_df.to_html(index=False).replace('\n','')

# %%
html_table
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th>age</th>      <th>sex</th>      <th>cp</th>      <th>trestbps</th>      <th>chol</th>      <th>fbs</th>      <th>restecg</th>      <th>thalach</th>      <th>exang</th>      <th>oldpeak</th>      <th>slope</th>      <th>ca</th>      <th>thal</th>      <th>target</th>    </tr>  </thead>  <tbody>    <tr>      <td>52</td>      <td>1</td>      <td>0</td>      <td>125</td>      <td>212</td>      <td>0</td>      <td>1</td>      <td>168</td>      <td>0</td>      <td>1.0</td>      <td>2</td>      <td>2</td>      <td>3</td>      <td>0</td>    </tr>    <tr>      <td>53</td>      <td>1</td>      <td>0</td>      <td>140</td>      <td>203</td>      <td>1</td>      <td>0</td>      <td>155</td>      <td>1</td>      <td>3.1</td>      <td>0</td>      <td>0</td>      <td>3</td>      <td>0</td>    </tr>    <tr>      <td>70</td>      <td>1</td>      <td>0</td>      <td>145</td>      <td>174</td>      <td>0</td>    
# ...
